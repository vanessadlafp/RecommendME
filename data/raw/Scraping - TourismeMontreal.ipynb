# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
import re

import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://www.mtl.org/en/experience/ultimate-guide-vintage-shopping-montreal"

response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

soup = BeautifulSoup(response.content, "html.parser")

#  Extract sections divided by <p class="h3"> headings and store information
sections = {}
stores = []

for section in soup.find_all("section", class_="block-wysiwyg"):
    heading = section.find("p", class_="h3")
    if heading:
        title = heading.get_text(strip=True)
        stores_info = []
        text = section.get_text(" ", strip=True)  # Extract section text as a whole
        
        for link in section.find_all("a", href=True):
            name = link.get_text(strip=True)
            url = link["href"]
            match = re.search(rf"{re.escape(name)}\s*\(([^)]+)\)", text)  # Extract address next to the store name
            address = match.group(1) if match else np.nan
            stores_info.append({"name": name, "url": url, "address": address})
            stores.append({"section": title, "name": name, "url": url, "address": address})
        sections[title] = {"content": text, "stores": stores_info}

# Create a pandas DataFrame
df = pd.DataFrame(stores).dropna()\
                         .reset_index(drop = True)  # All stores have addresses, if empty data was parsed incorrectly as store
df
# Out:
#                        section                           name  \
# 0             Hand-Picked Cool                  Annex x LOCAL
# 1             Hand-Picked Cool                        Ex-Voto
# 2             Hand-Picked Cool                            LNF
# 3             Hand-Picked Cool                   Lazy Vintage
# 4             Hand-Picked Cool                      Le Ninety
# 5             Hand-Picked Cool                 Bohème Vintage
# 6             Hand-Picked Cool                     Shwap Club
# 7             Hand-Picked Cool                    Common Sort
# 8             Hand-Picked Cool                Empire Exchange
# 9          Restored & Upcycled                Citizen Vintage
# 10         Restored & Upcycled          La Pompadour Boutique
# 11         Restored & Upcycled                  Covet Vintage
# 12         Restored & Upcycled                     Take Three
# 13         Restored & Upcycled               ERA Vintage Wear
# 14         Restored & Upcycled                     Cul-du-Sac
# 15           Hunter's Paradise                          Eva B
# 16           Hunter's Paradise                          Eva D
# 17           Hunter's Paradise                          Hadio
# 18           Hunter's Paradise                      KILOFripe
# 19           Hunter's Paradise                    Marché Floh
# 20           Hunter's Paradise                The Little Shop
# 21      Bring it to the Runway                  Rudston Brown
# 22      Bring it to the Runway                    Le Dressing
# 23      Bring it to the Runway             Les Folles Alliées
# 24      Bring it to the Runway                        Seconde
# 25      Bring it to the Runway                           RUSE
# 26      Bring it to the Runway                       Inedit.e
# 27           Unleash the Niche                    Palmo Goods
# 28           Unleash the Niche            La Caravane Vintage
# 29           Unleash the Niche                 Boutique Le 63
# 30           Unleash the Niche                     Mervmatsui
# 31           Unleash the Niche        Club Theos Montreal Inc
# 32           Unleash the Niche               Club 777 Vintage
# 33           Unleash the Niche                Ribotti Vintage
# 34           Unleash the Niche                 Kitsch'n Swell
# 35  Home Sweet Secondhand Home                     Style Labo
# 36  Home Sweet Secondhand Home  Spazio Architectural Antiques
# 37  Home Sweet Secondhand Home                        Re.ixue
#
#                                                   url  \
# 0                    https://www.annexvintage.com/us/
# 1                                https://exvoto.ca/en
# 2                            https://www.lnfshop.com/
# 3                            https://www.lazymtl.com/
# 4          https://www.instagram.com/le.ninety/?hl=en
# 5                          https://bohemevintage.com/
# 6                          https://www.shwapclub.com/
# 7                             https://commonsort.com/
# 8                              https://empiremtl.com/
# 9                     https://www.citizenvintage.com/
# 10                        https://lapompadourmtl.com/
# 11                          https://covetvintage.com/
# 12            https://www.boutiquetakethree.com/about
# 13                       https://eravintagewear.shop/
# 14      https://www.instagram.com/culdesac.mtl/?hl=en
# 15                          https://boutiqueevab.com/
# 16         https://boutiqueevab.com/collections/eva-d
# 17                    https://hadio.com/another-home/
# 18                             https://kilofripe.com/
# 19                            https://marchefloh.com/
# 20  https://www.instagram.com/thelittleshopmtl/?hl=en
# 21                   https://rudstonbrownvintage.com/
# 22                https://www.ledressingmontreal.com/
# 23  https://www.facebook.com/pages/category/Shoppi...
# 24   https://www.instagram.com/seconde.vintage/?hl=en
# 25                   https://www.ruseboutique.com/fc/
# 26         https://www.instagram.com/inedit.e_/?hl=en
# 27                        https://www.palmogoods.com/
# 28                 https://www.lacaravanevintage.com/
# 29      https://www.instagram.com/boutiquele63/?hl=en
# 30        https://www.instagram.com/mervmatsui/?hl=en
# 31     https://www.instagram.com/theosmontreal/?hl=en
# 32                        https://club777vintage.com/
# 33                      https://ribottivintage.com/en
# 34           https://www.boutiquekitschnswell.com/fc/
# 35                         http://stylelabo-deco.com/
# 36                             https://www.spazio.ca/
# 37                            https://www.reixue.com/
#
#                                               address
# 0                        5364 Saint-Laurent Boulevard
# 1                        6534 Saint-Laurent Boulevard
# 2                                    5319 Park Avenue
# 3   1682 Mont-Royal Avenue East, 3730 Ontario Stre...
# 4                             4361 Saint-Denis Street
# 5                              206 Saint-Viateur West
# 6                     4710 Saint-Ambroise Street #265
# 7                        3667 Saint-Laurent Boulevard
# 8                 5225 & 6796 Saint-Laurent Boulevard
# 9                        5330 Saint-Laurent Boulevard
# 10                       5358 Saint-Laurent Boulevard
# 11                       5413 Saint-Laurent Boulevard
# 12                       5594 Saint-Laurent Boulevard
# 13                         999 Du College Street, #41
# 14                       3794 Saint-Laurent Boulevard
# 15                       2015 Saint-Laurent Boulevard
# 16                       1611 Saint-Laurent Boulevard
# 17                         314 Mont-Royal Avenue East
# 18                       3800 Saint-Laurent Boulevard
# 19                            4301 Saint-Denis Street
# 20                                 1002 Ogilvy Avenue
# 21                        5879 Sherbrooke Street West
# 22                            3854 Saint-Denis Street
# 23                         371 Mont-Royal Avenue East
# 24                       5274 Saint-Laurent Boulevard
# 25                       5141 Saint-Laurent Boulevard
# 26                       6370 Saint-Laurent Boulevard
# 27                          263 Mont-Royal Avenue Est
# 28                       4116 Saint-Laurent Boulevard
# 29                           63 Mont-Royal Avenue Est
# 30                              1025 Avenue Van Horne
# 31                        1134A Mont-Royal Avenue Est
# 32                            4339 Saint-Denis Street
# 33                       5149 Saint-Laurent Boulevard
# 34                       4065 Saint-Laurent Boulevard
# 35                       5595 Saint-Laurent Boulevard
# 36                       8405 Saint-Laurent Boulevard
# 37                          262 Avenue Fairmount West

# %%
df.to_csv('thrift_stores.csv', index = False)

# %% [markdown]
# #### Extract Features from 'Content' section

# %%
# Method 1: Extracting Keywords
from sklearn.feature_extraction.text import TfidfVectorizer

# Extract content sections
content_list = [section.get_text(" ", strip=True) for section in soup.find_all("section", class_="block-wysiwyg")]

# Convert to DataFrame
df_content = pd.DataFrame({"section": sections.keys(), "content": content_list})

# Apply TF-IDF
vectorizer = TfidfVectorizer(stop_words="english", max_features=20)
tfidf_matrix = vectorizer.fit_transform(df_content["content"])
feature_names = vectorizer.get_feature_names_out()

# Create DataFrame with extracted features
df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)
df_features = pd.concat([df_content, df_tfidf], axis=1)

df_features.head()
# Out:
#                   section                                            content  \
# 0        Hand-Picked Cool  Hand-Picked Cool It is generally understood th...
# 1     Restored & Upcycled  Restored & Upcycled Another way to approach su...
# 2       Hunter's Paradise  Hunter's Paradise Looking to get lost? There's...
# 3  Bring it to the Runway  Bring it to the Runway If you're looking to in...
# 4       Unleash the Niche  Unleash the Niche As thrifting continues to ri...
#
#      avenue  boulevard     denis      east  garments     goods      hand  \
# 0  0.156113   0.338155  0.090387  0.210957  0.000000  0.000000  0.374804
# 1  0.000000   0.338451  0.000000  0.000000  0.316712  0.105571  0.250088
# 2  0.258914   0.336499  0.299814  0.174936  0.174936  0.000000  0.000000
# 3  0.143287   0.372449  0.165922  0.193626  0.193626  0.000000  0.000000
# 4  0.350686   0.227886  0.101521  0.000000  0.000000  0.236943  0.000000
#
#     laurent    little    modern      mont  montréal    pieces     royal  \
# 0  0.338155  0.078056  0.210957  0.090387  0.090387  0.078056  0.090387
# 1  0.338451  0.078125  0.105571  0.000000  0.090466  0.156250  0.000000
# 2  0.336499  0.129457  0.000000  0.149907  0.299814  0.000000  0.149907
# 3  0.372449  0.143287  0.000000  0.165922  0.000000  0.143287  0.165922
# 4  0.227886  0.175343  0.000000  0.304563  0.000000  0.087671  0.304563
#
#       saint  secondhand  selection     store    street   vintage
# 0  0.541048    0.000000   0.067631  0.078056  0.234169  0.338155
# 1  0.338451    0.211142   0.067690  0.078125  0.078125  0.609212
# 2  0.560831    0.174936   0.112166  0.129457  0.129457  0.112166
# 3  0.496598    0.000000   0.124150  0.143287  0.286575  0.372449
# 4  0.303847    0.000000   0.075962  0.087671  0.087671  0.607695

# %%
# Method 2: Sentiment Analysis
from textblob import TextBlob

df_content["sentiment"] = df_content["content"].apply(lambda text: TextBlob(text).sentiment.polarity)

print(df_content[["section", "sentiment"]])
# Out:
#                       section  sentiment
# 0            Hand-Picked Cool   0.183482
# 1         Restored & Upcycled   0.121042
# 2           Hunter's Paradise   0.127465
# 3      Bring it to the Runway   0.129924
# 4           Unleash the Niche   0.116488
# 5  Home Sweet Secondhand Home   0.411538

# %%
# Method 3: Named Entity Recognition (NER)
import spacy

nlp = spacy.load("en_core_web_sm")
df_content["entities"] = df_content["content"].apply(lambda text: [(ent.text, ent.label_) for ent in nlp(text).ents])

df_content[["section", "entities"]]
# Out:
#                       section  \
# 0            Hand-Picked Cool
# 1         Restored & Upcycled
# 2           Hunter's Paradise
# 3      Bring it to the Runway
# 4           Unleash the Niche
# 5  Home Sweet Secondhand Home
#
#                                             entities
# 0  [(seasonal, DATE), (Montréal, ORG), (Mile End'...
# 1  [(Restored & Upcycled, ORG), (5330, DATE), (Sa...
# 2  [(Hunter, PERSON), (afternoon, TIME), (Main, E...
# 3  [(Runway, ORG), (the 30s through the 90s, DATE...
# 4  [(Niche, ORG), (Palmo Goods, FAC), (263, CARDI...
# 5  [(Montréal, PERSON), (Style Labo, ORG), (5595,...
