# %%
import pandas as pd
import numpy as np

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import re

import warnings
warnings.filterwarnings("ignore")

# %%
# Load raw data
data = pd.read_csv('/Users/vanessafarias/RecommendME/data/raw/thrift_stores.csv')
print(data.shape)
data.head()
# Out:
# (38, 4)
#             section           name  \
# 0  Hand-Picked Cool  Annex x LOCAL
# 1  Hand-Picked Cool        Ex-Voto
# 2  Hand-Picked Cool            LNF
# 3  Hand-Picked Cool   Lazy Vintage
# 4  Hand-Picked Cool      Le Ninety
#
#                                           url  \
# 0            https://www.annexvintage.com/us/
# 1                        https://exvoto.ca/en
# 2                    https://www.lnfshop.com/
# 3                    https://www.lazymtl.com/
# 4  https://www.instagram.com/le.ninety/?hl=en
#
#                                              address
# 0                       5364 Saint-Laurent Boulevard
# 1                       6534 Saint-Laurent Boulevard
# 2                                   5319 Park Avenue
# 3  1682 Mont-Royal Avenue East, 3730 Ontario Stre...
# 4                            4361 Saint-Denis Street

# %%
def correct_address(address):
    """Returns the validated address, latitude, and longitude using OpenStreetMap."""
    # Initialize the Nominatim geocoder
    geolocator = Nominatim(user_agent="canada_address_validator")
    try:
        location = geolocator.geocode(address + ", Canada", timeout=10)
        if location:
            return location.address
        else:
            return None
    except GeocoderTimedOut:
        return None
    
def geocode_address(address):
    """Returns the validated address, latitude, and longitude using OpenStreetMap."""
    # Initialize the Nominatim geocoder
    geolocator = Nominatim(user_agent="canada_address_validator")
    try:
        location = geolocator.geocode(address + ", Canada", timeout=10)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except GeocoderTimedOut:
        return None, None
    
def clean_address(address):
    return re.sub(r",?\s*#\d+\w*", "", address) 

def extract_neighborhoods(address):
    parts = address.split(", ")  # Split by commas
    neighborhood_1 = parts[2] if len(parts) > 2 else None  # Position 2
    neighborhood_2 = parts[3] if len(parts) > 3 else None  # Position 3
    return pd.Series([neighborhood_1, neighborhood_2])

# %%
# Fix data formatting

# Store 1 
row_to_duplicate = data.loc[[3]]  # Select row 3
df = pd.concat([data, row_to_duplicate] , ignore_index=True)

# Fix address formatting using `.at[]` to avoid chained indexing
df.at[3, 'address'] = df.at[3, 'address'].split(',')[0]
df.at[38, 'address'] = df.at[38, 'address'].split(',')[1]

df.drop_duplicates(inplace = True)

# Store 2
# Fix data formatting
row_to_duplicate = data.loc[[8]]  # Select row 3
df2 = pd.concat([df, row_to_duplicate] , ignore_index=True)

empire_exchange_1 = '5225 Saint-Laurent Boulevard'
empire_exchange_2 = '6796 Saint-Laurent Boulevard'

# Fix address formatting using `.at[]` to avoid chained indexing
df2.at[8, 'address'] = empire_exchange_1
df2.at[39, 'address'] = empire_exchange_2

df2.drop_duplicates(inplace = True)

# translate key words in addresses
df2['address'] = df2.address.str.replace('East', 'Est')\
                            .str.replace('West', 'Ouest')\
                            .str.replace('Street', 'Rue')

# %%
# Remove unit # in address
df2['address'] = df2['address'].apply(clean_address)

# Specify city and province to improve accuracy
df2['address'] = df2['address'] + ', Montreal' + ', Quebec' 

# Geocode
df2['corrected_address'] = df2['address'].apply(correct_address)
df2['coordinates'] = df2['address'].apply(geocode_address)

# %%
# Apply function to extract neighborhoods
df2[["neighborhood", "neighborhood_2"]] = df2["corrected_address"].apply(extract_neighborhoods)

# Correct neighborhood
df2.loc[[8, 13, 15, 16, 17, 18, 19, 20, 22, 32, 38], 'neighborhood'] = df2.loc[[8, 13, 15, 16, 17, 18, 19, 20, 22, 32, 38], 'neighborhood_2']

df2.drop('neighborhood_2', axis = 1, inplace = True)

# %%
df2['latitude'] = df2['coordinates'].str[0]
df2['longitude'] = df2['coordinates'].str[1]

# %%
df2
# Out:
#                        section                           name  \
# 0             Hand-Picked Cool                  Annex x LOCAL
# 1             Hand-Picked Cool                        Ex-Voto
# 2             Hand-Picked Cool                            LNF
# 3             Hand-Picked Cool                   Lazy Vintage
# 4             Hand-Picked Cool                      Le Ninety
# 5             Hand-Picked Cool                 Bohème Vintage
# 6             Hand-Picked Cool                     Shwap Club
# 7             Hand-Picked Cool                    Common Sort
# 8             Hand-Picked Cool                Empire Exchange
# 9          Restored & Upcycled                Citizen Vintage
# 10         Restored & Upcycled          La Pompadour Boutique
# 11         Restored & Upcycled                  Covet Vintage
# 12         Restored & Upcycled                     Take Three
# 13         Restored & Upcycled               ERA Vintage Wear
# 14         Restored & Upcycled                     Cul-du-Sac
# 15           Hunter's Paradise                          Eva B
# 16           Hunter's Paradise                          Eva D
# 17           Hunter's Paradise                          Hadio
# 18           Hunter's Paradise                      KILOFripe
# 19           Hunter's Paradise                    Marché Floh
# 20           Hunter's Paradise                The Little Shop
# 21      Bring it to the Runway                  Rudston Brown
# 22      Bring it to the Runway                    Le Dressing
# 23      Bring it to the Runway             Les Folles Alliées
# 24      Bring it to the Runway                        Seconde
# 25      Bring it to the Runway                           RUSE
# 26      Bring it to the Runway                       Inedit.e
# 27           Unleash the Niche                    Palmo Goods
# 28           Unleash the Niche            La Caravane Vintage
# 29           Unleash the Niche                 Boutique Le 63
# 30           Unleash the Niche                     Mervmatsui
# 31           Unleash the Niche        Club Theos Montreal Inc
# 32           Unleash the Niche               Club 777 Vintage
# 33           Unleash the Niche                Ribotti Vintage
# 34           Unleash the Niche                 Kitsch'n Swell
# 35  Home Sweet Secondhand Home                     Style Labo
# 36  Home Sweet Secondhand Home  Spazio Architectural Antiques
# 37  Home Sweet Secondhand Home                        Re.ixue
# 38            Hand-Picked Cool                   Lazy Vintage
# 39            Hand-Picked Cool                Empire Exchange
#
#                                                   url  \
# 0                    https://www.annexvintage.com/us/
# 1                                https://exvoto.ca/en
# 2                            https://www.lnfshop.com/
# 3                            https://www.lazymtl.com/
# 4          https://www.instagram.com/le.ninety/?hl=en
# 5                          https://bohemevintage.com/
# 6                          https://www.shwapclub.com/
# 7                             https://commonsort.com/
# 8                              https://empiremtl.com/
# 9                     https://www.citizenvintage.com/
# 10                        https://lapompadourmtl.com/
# 11                          https://covetvintage.com/
# 12            https://www.boutiquetakethree.com/about
# 13                       https://eravintagewear.shop/
# 14      https://www.instagram.com/culdesac.mtl/?hl=en
# 15                          https://boutiqueevab.com/
# 16         https://boutiqueevab.com/collections/eva-d
# 17                    https://hadio.com/another-home/
# 18                             https://kilofripe.com/
# 17                  (45.5230695, -73.58353)
# 18                 (45.515427, -73.5762371)
# 19         (45.5179801, -73.56870587794859)
# 20                 (45.5251509, -73.627313)
# 21                (45.4691706, -73.6190046)
# 22                (45.5195693, -73.5736351)
# 23  (45.52381413636364, -73.58326974545454)
# 24                 (45.5242761, -73.595925)
# 25                (45.5235673, -73.5935616)
# 26                (45.5297279, -73.6078299)
# 27                 (45.522621, -73.5842881)
# 28                 (45.517427, -73.5809751)
# 29                (45.5208477, -73.5858412)
# 30                 (45.524688, -73.6113699)
# 31  (45.53921328221742, -73.56861612726624)
# 32         (45.5179801, -73.56870587794859)
# 33                (45.5236392, -73.5937025)
# 34                 (45.5172133, -73.579513)
# 35                (45.5263319, -73.5996568)
# 36         (45.5405712, -73.63614728836808)
# 37                (45.5207519, -73.5970964)
# 38                (45.5230629, -73.5610736)
# 39        (45.53239525, -73.61380872763017)
#
#                             neighborhood   latitude  longitude
# 0                               Mile-End  45.524801 -73.597082
# 1                       La Petite-Patrie  45.530786 -73.610191
# 2   Villeray–Saint-Michel–Parc-Extension  45.530093 -73.622396
# 3                  Le Plateau-Mont-Royal  45.532462 -73.574704
# 4                  Le Plateau-Mont-Royal  45.523209 -73.580771
# 5                               Mile-End  45.523164 -73.601104
# 6                     Rue Saint-Ambroise  45.469946 -73.586085
# 7                  Le Plateau-Mont-Royal  45.514592 -73.573708
# 8                               Mile-End  45.524204 -73.595011
# 9                               Mile-End  45.524589 -73.596677
# 10                              Mile-End  45.524877 -73.597191
# 11                              Mile-End  45.525421 -73.597386
# 12                              Mile-End  45.526009 -73.599737
# 13                           Saint-Henri  45.479064 -73.589192
# 14                 Le Plateau-Mont-Royal  45.515322 -73.576201
# 15                           Ville-Marie  45.511564 -73.567124
# 16               Quartier des Spectacles  45.511135 -73.566169
# 17                 Le Plateau-Mont-Royal  45.523069 -73.583530
# 18                 Le Plateau-Mont-Royal  45.515427 -73.576237
# 19                 Le Plateau-Mont-Royal  45.517980 -73.568706
# 20  Villeray–Saint-Michel–Parc-Extension  45.525151 -73.627313
# 21   Côte-des-Neiges–Notre-Dame-de-Grâce  45.469171 -73.619005
# 22                 Le Plateau-Mont-Royal  45.519569 -73.573635
# 23                 Le Plateau-Mont-Royal  45.523814 -73.583270
# 24                              Mile-End  45.524276 -73.595925
# 25                              Mile-End  45.523567 -73.593562
# 26                      La Petite-Patrie  45.529728 -73.607830
# 27                 Le Plateau-Mont-Royal  45.522621 -73.584288
# 28                 Le Plateau-Mont-Royal  45.517427 -73.580975
# 29                 Le Plateau-Mont-Royal  45.520848 -73.585841
# 30                             Outremont  45.524688 -73.611370
# 31                              Montréal  45.539213 -73.568616
# 32                 Le Plateau-Mont-Royal  45.517980 -73.568706
# 33                              Mile-End  45.523639 -73.593703
# 34                 Le Plateau-Mont-Royal  45.517213 -73.579513
# 35                              Mile-End  45.526332 -73.599657
# 36                              Villeray  45.540571 -73.636147
# 37                              Mile-End  45.520752 -73.597096
# 38                           Village gai  45.523063 -73.561074
# 39                      La Petite-Patrie  45.532395 -73.613809
